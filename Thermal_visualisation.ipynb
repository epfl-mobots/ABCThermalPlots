# %%
import thermalutil as tu
import pandas as pd
pd.set_option('display.expand_frame_repr', False)
import numpy as np
import matplotlib.pyplot as plt  # Needed for clabel
import pickle as pkl

# %%
file_path = '/Users/clarawetzel/Project/ABCThermalPlots/2021-11-24/abc07_tmp_2021-11-24.csv'
df = None
try:
    # Assuming data is in a structured format like CSV or similar
    df = pd.read_csv(file_path, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df.set_index('datetime', inplace=True)
    print(df)
 
except FileNotFoundError:
    print(f"File '{file_path}' not found.")

# fetch the first line of the .dat file
with open(file_path, 'r') as file:
    first_line = file.readline()
    print("First line (not in df) = " + first_line)
    second_line = file.readline()
    print("Second line (in df) = " + second_line)

temperatures = df.iloc[:, 1:65]
print(temperatures)

tu.preview(temperatures,show_sensors=True,rows=[3619, 8619, 0, 5000, 56, 7000])
# Out:
#                        timestamp       t00       t01       t02       t03       t04       t05        t06       t07       t08  ...        t54        t55        t56        t57        t58        t59        t60        t61        t62        t63
# datetime                                                                                                                     ...
# 2021-11-24T00:00:02Z  1637712002  8.992188  8.609375  8.109375  7.484375  9.031250  9.500000  10.093750  9.359375  9.093750  ...  16.398438  21.968750  14.671875  20.273438  24.046875  22.851562  13.664062  15.226562  16.671875  16.601562
# 2021-11-24T00:00:12Z  1637712012  8.984375  8.609375  8.109375  7.484375  9.039062  9.500000  10.101562  9.351562  9.093750  ...  16.398438  21.968750  14.679688  20.296875  24.054688  22.851562  13.656250  15.226562  16.664062  16.601562
# ...

# %%
df = pd.read_csv('/Users/clarawetzel/Project/ABCThermalPlots/abc07_tmp_2022-03-06.csv')
df.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)]
df.set_index('datetime', inplace=True)
line_csv = 4706
line_temp = 40

temperatures = df.iloc[:, 1:65]

tu.plot_temp(temperatures, line_csv, line_temp)

# %%
file_path_top = '/Users/clarawetzel/Project/ABCThermalPlots/2021-11-24/abc05_tmp_2021-11-24.csv'
df_top = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_top = pd.read_csv(file_path_top, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_top.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_top.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_top}' not found.")

file_path_bot = '/Users/clarawetzel/Project/ABCThermalPlots/2021-11-24/abc07_tmp_2021-11-24.csv'
df_bot = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_bot = pd.read_csv(file_path_bot, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_bot.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_bot.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_bot}' not found.")

temperatures_top = df_top.iloc[:, 1:65]
temperatures_bot = df_bot.iloc[:, 1:65]

#datetime : 10am
line_csv_top = 3634 
line_csv_bot = 3619

tu.preview_single(temperatures_top, temperatures_bot ,show_sensors=True,row_top=line_csv_top, row_bot = line_csv_bot, vmin=0, vmax=35)

tu.plot_temp(temperatures_bot, line_csv_bot)
# Out:
# ...
# Previewing thermal data:
# For the top frame : Max temp at 137, 1 for row 3634 [tmax = 8.120581545574922]
# For the bottom frame : Max temp at 132, 55 for row 3619 [tmax = 32.02548581933613]

# %%
file_path_top = '/Users/clarawetzel/Project/ABCThermalPlots/2021-11-17/abc05_tmp_2021-11-17.csv'
df_top = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_top = pd.read_csv(file_path_top, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_top.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_top.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_top}' not found.")

file_path_bot = '/Users/clarawetzel/Project/ABCThermalPlots/2021-11-17/abc07_tmp_2021-11-17.csv'
df_bot = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_bot = pd.read_csv(file_path_bot, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_bot.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_bot.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_bot}' not found.")

temperatures_top = df_top.iloc[:, 1:65]
temperatures_bot = df_bot.iloc[:, 1:65]


#datetime : 10:30pm
line_csv_top = 8132
line_csv_bot = 8133

tu.preview_single(temperatures_top, temperatures_bot ,show_sensors=True,row_top=line_csv_top, row_bot = line_csv_bot, vmin=0, vmax=35)

tu.plot_temp(temperatures_bot, line_csv_bot)
# Out:
# ...
# Previewing thermal data:
# For the top frame : Max temp at 311, 180 for row 8132 [tmax = 15.669331917338862]
# For the bottom frame : Max temp at 132, 55 for row 8133 [tmax = 28.898334129082393]

# %%
file_path_top = '/Users/clarawetzel/Project/ABCThermalPlots/2021-11-18/abc05_tmp_2021-11-18.csv'
df_top = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_top = pd.read_csv(file_path_top, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_top.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_top.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_top}' not found.")

file_path_bot = '/Users/clarawetzel/Project/ABCThermalPlots/2021-11-18/abc07_tmp_2021-11-18.csv'
df_bot = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_bot = pd.read_csv(file_path_bot, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_bot.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_bot.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_bot}' not found.")

temperatures_top = df_top.iloc[:, 1:65]
temperatures_bot = df_bot.iloc[:, 1:65]

#datetime : 11:00am
line_csv_top = 3979 
line_csv_bot = 3987 

tu.preview_single(temperatures_top, temperatures_bot ,show_sensors=True,row_top=line_csv_top, row_bot=line_csv_bot, vmin=0, vmax=35)

tu.plot_temp(temperatures_bot, line_csv_bot)
# Out:
# ...
# Previewing thermal data:
# For the top frame : Max temp at 0, 1 for row 3979 [tmax = 18.399947118356245]
# For the bottom frame : Max temp at 142, 71 for row 3987 [tmax = 34.613879601387644]

# %%
file_path_top = '/Users/clarawetzel/Project/ABCThermalPlots/2021-12-08/abc05_tmp_2021-12-08.csv'
df_top = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_top = pd.read_csv(file_path_top, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_top.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_top.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_top}' not found.")

file_path_bot = '/Users/clarawetzel/Project/ABCThermalPlots/2021-12-08/abc07_tmp_2021-12-08.csv'
df_bot = None
try:
    # Assuming data is in a structured format like CSV or similar
    df_bot = pd.read_csv(file_path_bot, delimiter=',', skiprows=1, header=None)
    # make the columns as being : datetime, 64 columns for sensor data and potentially one column for validity
    df_bot.columns = ['timestamp'] + ['datetime'] + [f't{i:02d}' for i in range(64)] 
    df_bot.set_index('datetime', inplace=True)
 
except FileNotFoundError:
    print(f"File '{file_path_bot}' not found.")

temperatures_top = df_top.iloc[:, 1:65]
temperatures_bot = df_bot.iloc[:, 1:65]

#datetime : 05:00am
line_csv_top = 1431
line_csv_bot = 1433

tu.preview_single(temperatures_top, temperatures_bot ,show_sensors=True,row_top=line_csv_top, row_bot=line_csv_bot, vmin=0, vmax=35)

tu.plot_temp(temperatures_bot, line_csv_bot)
# Out:
# ...
# Previewing thermal data:
# For the top frame : Max temp at 241, 17 for row 1431 [tmax = 11.599581719681185]
# For the bottom frame : Max temp at 205, 129 for row 1433 [tmax = 29.892672870980153]
